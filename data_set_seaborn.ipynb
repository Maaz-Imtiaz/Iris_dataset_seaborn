# %%
import seaborn as sns
import pandas as pd

# %%
file_path = 'Iris.csv'
df = pd.read_csv(file_path)
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.corr()
# Out:
# <ipython-input-11-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %%
sns.heatmap(df.corr())
# Out:
# <ipython-input-12-aa4f4450a243>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
sns.jointplot(x='SepalLengthCm',y='PetalLengthCm',data=df,kind='hex')

# %%
sns.jointplot(x='SepalLengthCm',y='PetalLengthCm',data=df,kind='reg')

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='PetalWidthCm')

# %%
sns.distplot(df['SepalLengthCm'])
# Out:
# <ipython-input-17-30f60815575f>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['SepalLengthCm'])
# <Axes: xlabel='SepalLengthCm', ylabel='Density'>

# %%
sns.distplot(df['SepalLengthCm'],kde=False,bins=10)
# Out:
# <ipython-input-21-a622bb8dc927>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['SepalLengthCm'],kde=False,bins=10)
# <Axes: xlabel='SepalLengthCm'>

# %%
sns.countplot(x='SepalLengthCm',data=df)
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='count'>

# %%
sns.countplot(y='SepalLengthCm',data=df)
# Out:
# <Axes: xlabel='count', ylabel='SepalLengthCm'>

# %%
sns.barplot(x='PetalWidthCm',y='SepalLengthCm',data=df)
# Out:
# <Axes: xlabel='PetalWidthCm', ylabel='SepalLengthCm'>

# %%
sns.barplot(x='SepalLengthCm',y='PetalWidthCm',data=df)
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='PetalWidthCm'>

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.boxplot(x='PetalLengthCm',y='PetalWidthCm', data=df)
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='PetalWidthCm'>

# %%
sns.boxplot(x="PetalLengthCm", y="PetalWidthCm", data=df,palette='rainbow')
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='PetalWidthCm'>

# %%
sns.boxplot(data=df,orient='v')
# Out:
# <Axes: >

# %%
sns.boxplot(x="SepalWidthCm", y="PetalWidthCm", hue="Species",data=df)
# Out:
# <Axes: xlabel='SepalWidthCm', ylabel='PetalWidthCm'>

# %%
sns.violinplot(x="SepalWidthCm", y="Species", data=df,palette='rainbow')
# Out:
# <Axes: xlabel='SepalWidthCm', ylabel='Species'>
